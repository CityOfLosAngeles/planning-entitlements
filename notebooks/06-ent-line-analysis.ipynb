# %% [markdown]
# # Entitlements near bus/rail lines
# * Subset: parcels that had TOC or non-TOC activity
# * Using reconstructed TOC Tiers map, we assign developments to specific transit lines.
# * Which bus/rail lines or rail stations have seen the most TOC entitlement activity?
# * All entitlement activity by bus/rail line & tier
# * All entitlement activity by rail line
# * Which ones have seen lots of entitlements or non-TOC entitlement activity?

# %%
import intake
from IPython.display import display, Markdown
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import geopandas as gpd
import utils
import boto3
import xlsxwriter

# %%
catalog = intake.open_catalog("../catalogs/*.yml")

s3 = boto3.client('s3')
bucket_name = 'city-planning-entitlements'

# %% [markdown]
# ## Assign entitlements to conditions

# %%
toc_tiers = utils.reconstruct_toc_tiers_file()

parcels = gpd.read_file(
    f"s3://{bucket_name}/gis/intermediate/toc_eligible_parcels_with_entitlements.geojson"
).to_crs({'init':'epsg:4326'})

# %%
parcels_with_activity = parcels[(parcels.num_TOC > 0) | (parcels.num_nonTOC > 0)]

# %%
df = utils.parcels_join_toc_tiers(parcels_with_activity, toc_tiers)

# %%
df['ENT'] = df.num_TOC + df.num_nonTOC

# %% [markdown]
# ## Which rule?

# %%
tier_1 = df[df.TOC_Tier == 1]
tier_2 = df[df.TOC_Tier == 2]
tier_3 = df[df.TOC_Tier == 3]
tier_4 = df[df.TOC_Tier == 4]

# %%
table = np.zeros(shape=(5, 4))
table[4,3] = tier_4[(tier_4.mode_a=="metro") & (tier_4.mode_b.isin(["metro", "bus"]))].ENT.sum()
table[4,2] = tier_4[tier_4.mode_a=="metro"].ENT.sum()
table[3,2] = tier_3[tier_3.mode_a=="metrolink"].ENT.sum()
table[3,1] = tier_2[tier_2.mode_a=="metrolink"].ENT.sum()
table[3,0] = tier_1[tier_1.mode_a=="metrolink"].ENT.sum()
table[2,2] = tier_3[tier_3.a_rapid & tier_3.b_rapid].ENT.sum()
table[2,1] = tier_2[tier_2.a_rapid & tier_2.b_rapid].ENT.sum()
table[1,2] = tier_3[tier_3.a_rapid ^ tier_3.b_rapid].ENT.sum()
table[1,1] = tier_2[tier_2.a_rapid ^ tier_2.b_rapid].ENT.sum()
table[1,0] = tier_1[tier_1.a_rapid ^ tier_1.b_rapid].ENT.sum()
table[0,1] = tier_2[~tier_2.a_rapid & ~tier_2.b_rapid].ENT.sum()
table[0,0] = tier_1[~tier_1.a_rapid & ~tier_1.b_rapid].ENT.sum()


fig, ax = plt.subplots(figsize=(16,16))
pos = ax.imshow(table, cmap="magma")
ax.set_axis_off()
ax.text(-2.1, 0.0, "Two Regular Buses", fontsize=24)
ax.text(-2.1, 1.0, "Regular plus Rapid Bus", fontsize=24)
ax.text(-2.1, 2.0, "Two Rapid Buses", fontsize=24)
ax.text(-2.1, 3.0, "Metrolink Rail Stations", fontsize=24)
ax.text(-2.1, 4.0, "Metro Rail Stations", fontsize=24)
ax.text(-0.2, -0.6, "Tier 1", fontsize=24)
ax.text(0.8, -0.6, "Tier 2", fontsize=24)
ax.text(1.8, -0.6, "Tier 3", fontsize=24)
ax.text(2.8, -0.6, "Tier 4", fontsize=24)
cb = fig.colorbar(pos, ax=ax)
cb.ax.tick_params(labelsize=16)
ax.text(0.6, -1.0, "TOC or Non-TOC Entitlements", fontsize=36)
#plt.savefig("toc.png", bbox_inches='tight')
# Out:
# Text(0.6, -1.0, 'TOC or Non-TOC Entitlements')

# %% [markdown]
# ## By Tier and Line

# %%
output_dfs = {}

def summarize(tier, header, tier_number):
    display(Markdown(header))
    metro_rail_summary = (
        tier[tier.mode_a=="metro"].groupby(["station_name", "line_name_a"])
        .agg({"num_TOC":"sum", "num_nonTOC":"sum", "ENT":"sum"})
        .sort_values(["ENT", "num_TOC", "num_nonTOC"], ascending = [False, False, False])
        .assign(tier = tier_number)
    )
    if len(metro_rail_summary):
        display(Markdown("#### Metro Rail"))
        display(metro_rail_summary)
        key = f'tier{tier_number}_metro'
        output_dfs[key] = metro_rail_summary.sort_values(
            ["ENT", "num_TOC", "num_nonTOC"], ascending = [False, False, False])
    
    metrolink_summary = (
        tier[tier.mode_a=="metrolink"].groupby("station_name")
        .agg({"num_TOC":"sum", "num_nonTOC":"sum", "ENT":"sum"})
        .sort_values(["ENT", "num_TOC", "num_nonTOC"], ascending = [False, False, False])
        .assign(tier = tier_number)
    )
    metrolink_summary = metrolink_summary.reindex(
        index=metrolink_summary.index.rename("station_name")
    )
    if len(metrolink_summary):
        display(Markdown("#### Metrolink"))
        display(metrolink_summary)
        key = f'tier{tier_number}_metrolink'
        output_dfs[key] = metrolink_summary.sort_values(
            ["ENT", "num_TOC", "num_nonTOC"], ascending = [False, False, False])
        
    a = tier[tier.mode_a=="bus"].groupby("line_name_a").agg({"num_TOC":"sum", "num_nonTOC":"sum", "ENT":"sum"})
    b = tier[tier.mode_b=="bus"].groupby("line_name_b").agg({"num_TOC":"sum", "num_nonTOC":"sum", "ENT":"sum"})
    bus_summary = (
        a.reindex(
            index=(a.index | b.index).rename("Bus Route")
        ).fillna(0).astype("int") + 
        b.reindex(
            index=(a.index | b.index).rename("Bus Route")
        ).fillna(0).astype("int")
    )
    bus_summary['tier'] = tier_number

    if len(bus_summary):
        display(Markdown("#### Bus Lines"))
        display(bus_summary.sort_values(["ENT", "num_TOC", "num_nonTOC"], 
                                        ascending=[False, False, False]).head(60))
        key = f'tier{tier_number}_bus'
        output_dfs[key] = bus_summary.sort_values(
            ["ENT", "num_TOC", "num_nonTOC"], ascending = [False, False, False])

# %%
# TODO: Figure out a better deduplicating strategy.
summarize(tier_1.drop_duplicates(subset=["AIN"]), "## Tier 1 Statistics", 1)
summarize(tier_2.drop_duplicates(subset=["AIN"]), "## Tier 2 Statistics", 2)
summarize(tier_3.drop_duplicates(subset=["AIN"]), "## Tier 3 Statistics", 3)
summarize(tier_4.drop_duplicates(subset=["AIN"]), "## Tier 4 Statistics", 4)
# Out:
# ## Tier 1 Statistics
# #### Metrolink
#                               num_TOC  num_nonTOC  ENT
# station_name
# Chatsworth Metrolink Station        0           3    3
# Northridge Metrolink Station        0           2    2
# Glendale Metrolink Station          0           1    1
# #### Bus Lines
#            num_TOC  num_nonTOC  ENT
# Bus Route
# 33               0          65   65
# 4               12          37   49
# 704              7          32   39
# 1                0          37   37
# 3                0          28   28
# 14/37            4          19   23
# 212/312          0          23   23
# 754              3          14   17
# 224              4          12   16
# 152/353          3          13   16
# 204              0          14   14
# 233              4           8   12
# 35/38            1          11   12
# 2/302            5           5   10
# 165              0          10   10
# 163/162          2           7    9
# 757              2           7    9
# 150/240          1           7    8
# 76               1           7    8
# 78/79/378        1           7    8
# 207              2           4    6
# 710              1           5    6
# 603              2           3    5
# 501              1           4    5
# 217              0           5    5
# 780              0           5    5
# 164              2           2    4
# 200              1           3    4
# 750              1           3    4
# 105              0           4    4
# CC 1             0           4    4
# 728              0           3    3
# R12              0           3    3
# 115              0           2    2
# 166/364          0           2    2
# 30/330           0           2    2
# 45               0           2    2
# 7                0           2    2
# 705              0           2    2
# 10/48            0           1    1
# 117              0           1    1
# 40               0           1    1
# 53               0           1    1
# 70               0           1    1
# 745              0           1    1
# 751              0           1    1
# 81               0           1    1
# 910/950          0           1    1
# ## Tier 2 Statistics
# #### Bus Lines
#            num_TOC  num_nonTOC  ENT
# Bus Route
# 757              4          31   35
# 207              3          29   32
# 204              8          13   21
# 754              8          13   21
# 4                4          16   20
# 603              2          18   20
# 780              1          19   20
# 206              9           8   17
# 704              5          12   17
# 200              2          12   14
# 728             11           2   13
# 33              10           2   12
# 14/37            2          10   12
# 150/240          0          10   10
# 217              0          10   10
# R12              9           0    9
# 10/48            2           6    8
# 212/312          2           5    7
# 750              0           7    7
# 710              1           5    6
# 2/302            0           6    6
# 7                3           2    5
# 152/353          0           5    5
# 111              1           3    4
# 30/330           1           3    4
# 165              0           4    4
# 35/38            0           4    4
# CC 6R            1           2    3
# 163/162          0           3    3
# 180/181          0           3    3
# 3                0           3    3
# 705              0           3    3
# 1                1           1    2
# 233              0           2    2
# 53               0           2    2
# 115              1           0    1
# 51/52/351        1           0    1
# 105              0           1    1
# 110              0           1    1
# 164              0           1    1
# 40               0           1    1
# 45               0           1    1
# 751              0           1    1
# 910/950          0           1    1
# CC 1             0           1    1
# ## Tier 3 Statistics
# #### Metro Rail
#                                                              num_TOC  \
# station_name                             line_name_a
# Hollywood / Vine Station                 Red                       2
# North Hollywood Station                  Red                       7
# Wilshire / Vermont Station               Red/Purple                8
# Vermont / Sunset Station                 Red                       4
# Wilshire / Normandie Station             Purple                    9
# Westlake / MacArthur Park Station        Red/Purple               10
# Highland Park Station                    Gold                      0
# Culver City Station                      EXPO                      0
# Hollywood / Highland Station             Red                       0
# Vermont / Beverly Station                Red                       3
# Wilshire/Fairfax                         Purple                    3
# Hollywood / Western Station              Red                       2
# Expo / Sepulveda Station                 EXPO                      2
# 103rd Street / Watts Towers  Station     Blue                      0
# Westwood/VA Hospital                     Purple                    1
# Vermont / Santa Monica Station           Red                       0
# Pico / Aliso Station                     Gold                      3
# Westwood/UCLA                            Purple                    1
# Southwest Museum Station                 Gold                      0
# Wilshire/La Cienega                      Purple                    2
# Chinatown Station                        Gold                      1
# Grand / LATTC Station                    Blue                      0
# Florence/Hindry                          Crenshaw                  5
# Civic Center / Grand Park Station        Red/Purple                0
# Expo / Bundy Station                     EXPO                      3
# Universal / Studio City Station          Red                       1
# Expo / Crenshaw Station                  EXPO                      0
# Westwood / Rancho Park Station           EXPO                      2
# Harbor Freeway Station                   Green                     0
# Jefferson / USC Station                  EXPO                      0
# Soto Station                             Gold                      0
# Wilshire/La Brea                         Purple                    0
# Florence/West                            Crenshaw                  2
# Wilshire / Western Station               Purple                    2
# Expo / Vermont Station                   EXPO                      1
# Pico Station                             Blue/EXPO                 1
# 2nd Place/Hope Street                    Regional Connector        0
# Heritage Square / Arroyo Station         Gold                      0
# LATTC / Ortho Institute Station          EXPO                      0
# Leimert Park                             Crenshaw                  0
# Union Station - Metro Red & Purple Lines Red/Purple                0
# Aviation/Century                         Crenshaw                  0
# Crenshaw/Slauson                         Crenshaw                  0
# Expo / La Brea Station                   EXPO                      0
# Farmdale Station                         EXPO                      0
# Lincoln Heights / Cypress Park Station   Gold                      0
#
#                                                              num_nonTOC  ENT
# station_name                             line_name_a
# Hollywood / Vine Station                 Red                         34   36
# North Hollywood Station                  Red                         17   24
# Wilshire / Vermont Station               Red/Purple                  14   22
# Vermont / Sunset Station                 Red                         18   22
# Wilshire / Normandie Station             Purple                       7   16
# Westlake / MacArthur Park Station        Red/Purple                   5   15
# Highland Park Station                    Gold                        13   13
# Culver City Station                      EXPO                        12   12
# Hollywood / Highland Station             Red                         12   12
# Vermont / Beverly Station                Red                          7   10
# Wilshire/Fairfax                         Purple                       7   10
# Hollywood / Western Station              Red                          8   10
# Expo / Sepulveda Station                 EXPO                         7    9
# 103rd Street / Watts Towers  Station     Blue                         9    9
# Westwood/VA Hospital                     Purple                       7    8
# Vermont / Santa Monica Station           Red                          8    8
# Pico / Aliso Station                     Gold                         4    7
# Westwood/UCLA                            Purple                       6    7
# Southwest Museum Station                 Gold                         7    7
# Wilshire/La Cienega                      Purple                       4    6
# Chinatown Station                        Gold                         5    6
# Grand / LATTC Station                    Blue                         6    6
# Florence/Hindry                          Crenshaw                     0    5
# Civic Center / Grand Park Station        Red/Purple                   5    5
# Expo / Bundy Station                     EXPO                         1    4
# Universal / Studio City Station          Red                          3    4
# Expo / Crenshaw Station                  EXPO                         4    4
# Westwood / Rancho Park Station           EXPO                         1    3
# Harbor Freeway Station                   Green                        3    3
# Jefferson / USC Station                  EXPO                         3    3
# Soto Station                             Gold                         3    3
# Wilshire/La Brea                         Purple                       3    3
# Florence/West                            Crenshaw                     0    2
# Wilshire / Western Station               Purple                       0    2
# Expo / Vermont Station                   EXPO                         1    2
# Pico Station                             Blue/EXPO                    1    2
# 2nd Place/Hope Street                    Regional Connector           2    2
# Heritage Square / Arroyo Station         Gold                         2    2
# LATTC / Ortho Institute Station          EXPO                         2    2
# Leimert Park                             Crenshaw                     2    2
# Union Station - Metro Red & Purple Lines Red/Purple                   2    2
# Aviation/Century                         Crenshaw                     1    1
# Crenshaw/Slauson                         Crenshaw                     1    1
# Expo / La Brea Station                   EXPO                         1    1
# Farmdale Station                         EXPO                         1    1
# Lincoln Heights / Cypress Park Station   Gold                         1    1
# #### Bus Lines
#            num_TOC  num_nonTOC  ENT
# Bus Route
# 757             15          95  110
# 720             32          64   96
# 754             13          40   53
# 780              9          39   48
# 207              6          37   43
# 704             15          22   37
# 4               12          16   28
# 745              0          25   25
# 217              9          15   24
# 901              7          17   24
# 705              6          16   22
# CC 6R            3          19   22
# 40               0          22   22
# 710              5          16   21
# 910/950          1          18   19
# 770              0          19   19
# 204              4          13   17
# 14/37            0          15   15
# 33               6           8   14
# 105              4          10   14
# 1                3           9   12
# 728              2           7    9
# 180/181          0           9    9
# 35/38            0           9    9
# 7                0           8    8
# R12              4           3    7
# 20               0           7    7
# 751              0           5    5
# 110              3           1    4
# CC 1             2           2    4
# 206              1           3    4
# 750              1           3    4
# 10/48            0           4    4
# 212/312          0           4    4
# 55/355           0           3    3
# 760              0           3    3
# 66               1           1    2
# 2/302            0           2    2
# 200              0           2    2
# 28               0           2    2
# 3                0           2    2
# 45               0           2    2
# 81               0           2    2
# 603              1           0    1
# 108/358          0           1    1
# 16/17/316        0           1    1
# 30/330           0           1    1
# 51/52/351        0           1    1
# 60               0           1    1
# 70               0           1    1
# ## Tier 4 Statistics
# #### Metro Rail
#                                                                        num_TOC  \
# station_name                                       line_name_a
# Hollywood / Vine Station                           Red                       0
# Pershing Square Station                            Red/Purple                0
# Wilshire / Western Station                         Purple                    2
# Westwood/UCLA                                      Purple                    0
# Vermont / Santa Monica Station                     Red                       3
# 7th St / Metro Center Station - Metro Red & Pur... Red/Purple                0
# 2nd Street/Broadway                                Regional Connector        0
# Hollywood / Highland Station                       Red                       1
# Crenshaw/Slauson                                   Crenshaw                  0
# Wilshire/La Brea                                   Purple                    0
# Vermont / Sunset Station                           Red                       3
# Wilshire / Normandie Station                       Purple                    1
# Vermont / Beverly Station                          Red                       0
# 1st Street Central Avenue                          Regional Connector        0
# Expo / Crenshaw Station                            EXPO                      0
# Hollywood / Western Station                        Red                       0
# Wilshire / Vermont Station                         Red/Purple                0
# 2nd Place/Hope Street                              Regional Connector        0
# La Cienega / Jefferson Station                     EXPO                      0
# Little Tokyo / Arts District Station               Gold                      0
#
#                                                                        num_nonTOC  \
# station_name                                       line_name_a
# Hollywood / Vine Station                           Red                         35
# Pershing Square Station                            Red/Purple                  16
# Wilshire / Western Station                         Purple                       7
# Westwood/UCLA                                      Purple                       9
# Vermont / Santa Monica Station                     Red                          4
# 7th St / Metro Center Station - Metro Red & Pur... Red/Purple                   7
# 2nd Street/Broadway                                Regional Connector           6
# Hollywood / Highland Station                       Red                          3
# Crenshaw/Slauson                                   Crenshaw                     4
# Wilshire/La Brea                                   Purple                       4
# Vermont / Sunset Station                           Red                          0
# Wilshire / Normandie Station                       Purple                       2
# Vermont / Beverly Station                          Red                          3
# 1st Street Central Avenue                          Regional Connector           2
# Expo / Crenshaw Station                            EXPO                         2
# Hollywood / Western Station                        Red                          2
# Wilshire / Vermont Station                         Red/Purple                   2
# 2nd Place/Hope Street                              Regional Connector           1
# La Cienega / Jefferson Station                     EXPO                         1
# Little Tokyo / Arts District Station               Gold                         1
#
#                                                                        ENT
# station_name                                       line_name_a
# Hollywood / Vine Station                           Red                  35
# Pershing Square Station                            Red/Purple           16
# Wilshire / Western Station                         Purple                9
# Westwood/UCLA                                      Purple                9
# Vermont / Santa Monica Station                     Red                   7
# 7th St / Metro Center Station - Metro Red & Pur... Red/Purple            7
# 2nd Street/Broadway                                Regional Connector    6
# Hollywood / Highland Station                       Red                   4
# Crenshaw/Slauson                                   Crenshaw              4
# Wilshire/La Brea                                   Purple                4
# Vermont / Sunset Station                           Red                   3
# Wilshire / Normandie Station                       Purple                3
# Vermont / Beverly Station                          Red                   3
# 1st Street Central Avenue                          Regional Connector    2
# Expo / Crenshaw Station                            EXPO                  2
# Hollywood / Western Station                        Red                   2
# Wilshire / Vermont Station                         Red/Purple            2
# 2nd Place/Hope Street                              Regional Connector    1
# La Cienega / Jefferson Station                     EXPO                  1
# Little Tokyo / Arts District Station               Gold                  1
# #### Bus Lines
#            num_TOC  num_nonTOC  ENT
# Bus Route
# 757              0          37   37
# 720              1          33   34
# 710              2          13   15
# 704              3           4    7
# 910/950          0           7    7
# 754              3           3    6
# 728              0           6    6
# 780              1           3    4
# 705              0           1    1
# 760              0           1    1

# %%
for key, value in output_dfs.items():
    display(key)
# Out:
# 'tier1_metrolink'
# 'tier1_bus'
# 'tier2_bus'
# 'tier3_metro'
# 'tier3_bus'
# 'tier4_metro'
# 'tier4_bus'

# %% [markdown]
# ## By Line

# %%
def summarize(df):
    # Bus
    bus_df = df[(df.mode_a == "bus") | (df.mode_b == "bus")]

    a = bus_df[bus_df.mode_a=="bus"].groupby("line_name_a").agg(
        {"num_TOC":"sum", "num_nonTOC":"sum", "ENT":"sum"})
    b = bus_df[bus_df.mode_b=="bus"].groupby("line_name_b").agg(
        {"num_TOC":"sum", "num_nonTOC":"sum", "ENT":"sum"})
    bus_summary = (
        a.reindex(
            index=(a.index | b.index).rename("Bus Route")
        ).fillna(0).astype("int") + 
        b.reindex(
            index=(a.index | b.index).rename("Bus Route")
        ).fillna(0).astype("int")
    )

    if len(bus_summary):
        display(Markdown("#### Bus Lines"))
        display(bus_summary.sort_values(["ENT", "num_TOC", "num_nonTOC"], 
                                        ascending = [False, False, False]).head(30))
        key = 'bus'
        output_dfs[key] = bus_summary.sort_values(
            ["ENT", "num_TOC", "num_nonTOC"], ascending = [False, False, False])
    
    # Metrolink
    metrolink_df = df[df.mode_a == "metrolink"]
    
    metrolink_summary = (
        metrolink_df.groupby(["station_name"])
        .agg({"num_TOC": "sum", "num_nonTOC":"sum", "ENT":"sum"})
        .sort_values(["ENT", "num_TOC", "num_nonTOC"], 
                                        ascending = [False, False, False])
    )
    metrolink_summary = metrolink_summary.reindex(
        index=metrolink_summary.index.rename("station_name")
    )
    
    if len(metrolink_summary):
        display(Markdown("#### Metrolink"))
        display(metrolink_summary)
        key = 'metrolink'
        output_dfs[key] = metrolink_summary.sort_values(
            ["ENT", "num_TOC", "num_nonTOC"], ascending = [False, False, False])

    # Metro Rail
    metro_df = df[(df.mode_a == "metro") | (df.mode_b == "metro")]

    metro_rail_summary = (
        metro_df.groupby("line_name_a")
        .agg({"num_TOC":"sum", "num_nonTOC":"sum", "ENT":"sum"})
        .sort_values(["ENT", "num_TOC", "num_nonTOC"], 
                                        ascending = [False, False, False])
    )
    metro_rail_summary = metro_rail_summary.reindex(
        index=metro_rail_summary.index.rename("Rail Line")
    )
    
    if len(metro_rail_summary):
        display(Markdown("#### Metro Rail"))
        display(metro_rail_summary)
        key = 'metro'
        output_dfs[key] = metro_rail_summary.sort_values(
            ["ENT", "num_TOC", "num_nonTOC"], ascending = [False, False, False])

# %%
summarize(df)
# Out:
# #### Bus Lines
#            num_TOC  num_nonTOC  ENT
# Bus Route
# 757             60         319  379
# 780             41         276  317
# 720             60         252  312
# 4               86         218  304
# 754             77         226  303
# 704             78         194  272
# 728             33         230  263
# 910/950          1         262  263
# 745              2         203  205
# 14/37           18         181  199
# 33              27         170  197
# 760              0         191  191
# 770              2         162  164
# 212/312         12         147  159
# 35/38           11         143  154
# 207             35         114  149
# 200             23         115  138
# 204             30         107  137
# 10/48           28          97  125
# 217             20         103  123
# 603             26          91  117
# 710             20          89  109
# 2/302           17          80   97
# 28               7          83   90
# 705             14          65   79
# 30/330          10          64   74
# CC 1             2          70   72
# CC 6R            6          65   71
# 20               2          68   70
# 81               0          69   69
# #### Metrolink
#                               num_TOC  num_nonTOC  ENT
# station_name
# Chatsworth Metrolink Station        0           3    3
# Glendale Metrolink Station          0           3    3
# Van Nuys Metrolink Station          2           0    2
# Northridge Metrolink Station        0           2    2
# #### Metro Rail
#                     num_TOC  num_nonTOC  ENT
# Rail Line
# Red                      56         328  384
# Red/Purple               36         294  330
# Purple                   76         250  326
# Regional Connector        0         132  132
# Gold                     11          93  104
# Blue/EXPO                 1          91   92
# EXPO                      9          68   77
# Blue                      1          44   45
# Crenshaw                 12          17   29
# Green                     0          15   15

# %% [markdown]
# ## Export output -- need to adapt for all ENT

# %%
bus_by_tier = pd.concat([
    output_dfs['tier1_bus'], 
    output_dfs['tier2_bus'], 
    output_dfs['tier3_bus'],
    output_dfs['tier4_bus'],
], axis = 0, sort = False).reset_index()

# %%
bus_total = (
    bus_by_tier.groupby('Bus Route')
    .agg({'ENT':'sum'})
    .reset_index()
    .rename(columns = {'ENT':'line_ENT'})
)

bus_by_tier = pd.merge(bus_by_tier, bus_total, on = 'Bus Route', how = 'left')

bus_by_tier['pct_TOC'] = bus_by_tier.num_TOC / bus_by_tier.line_TOC

bus_by_tier = bus_by_tier.sort_values(['line_TOC', 'num_TOC'], ascending = [False, False])

# %%
metro_by_tier = pd.concat([
    output_dfs['tier3_metro'], 
    output_dfs['tier4_metro'], 
], axis = 0, sort = False).reset_index()

# %%
metro_total = (
    metro_by_tier.groupby(['line_name_a'])
    .agg({'num_TOC':'sum'})
    .reset_index()
    .rename(columns = {'num_TOC':'line_TOC'})
)

metro_by_tier = pd.merge(metro_by_tier, metro_total, on = 'line_name_a', how = 'left')

metro_by_tier['pct_TOC'] = metro_by_tier.num_TOC / metro_by_tier.line_TOC

metro_by_tier = metro_by_tier.sort_values(['line_TOC', 'num_TOC'], ascending = [False, False])

# %%
writer = pd.ExcelWriter('../outputs/06-ent-line-analysis.xlsx', engine='xlsxwriter')

bus_by_tier.to_excel(writer, sheet_name = 'bus_by_tier')
metro_by_tier.to_excel(writer, sheet_name = 'metro_by_tier')

for key, value in output_dfs.items():
    if key.find('tier') is -1:
        value.to_excel(writer, sheet_name = key)

writer.save()
